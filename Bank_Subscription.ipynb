# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"D:\data analyst\Interview_task\bank_dataset.csv")

# %%
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
df.shape
# Out:
# (45211, 17)

# %% [markdown]
# - there are 45211 rows  and 17 columns

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %% [markdown]
# - these are the columns in the data set

# %%
df.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %%
df.isna().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %% [markdown]
# - there is no null values in the data set

# %% [markdown]
# df.info()

# %%
df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %% [markdown]
# - these are the count,age,min,max of the int values in the data set

# %%
df[['age','balance','day','duration','campaign','pdays','previous']].corr()
# Out:
#                age   balance       day  duration  campaign     pdays  previous
# age       1.000000  0.097783 -0.009120 -0.004648  0.004760 -0.023758  0.001288
# balance   0.097783  1.000000  0.004503  0.021560 -0.014578  0.003435  0.016674
# day      -0.009120  0.004503  1.000000 -0.030206  0.162490 -0.093044 -0.051710
# duration -0.004648  0.021560 -0.030206  1.000000 -0.084570 -0.001565  0.001203
# campaign  0.004760 -0.014578  0.162490 -0.084570  1.000000 -0.088628 -0.032855
# pdays    -0.023758  0.003435 -0.093044 -0.001565 -0.088628  1.000000  0.454820
# previous  0.001288  0.016674 -0.051710  0.001203 -0.032855  0.454820  1.000000

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df[['age','balance','day','duration','campaign','pdays','previous']].corr(),cbar = True,annot = True,cmap = "Blues")
# Out:
# <Axes: >

# %% [markdown]
# - Previous and pdays is showing small positive correlation
# - balance and age have positive correlation

# %%
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
df['age'].unique()
# Out:
# array([58, 44, 33, 47, 35, 28, 42, 43, 41, 29, 53, 57, 51, 45, 60, 56, 32,
#        25, 40, 39, 52, 46, 36, 49, 59, 37, 50, 54, 55, 48, 24, 38, 31, 30,
#        27, 34, 23, 26, 61, 22, 21, 20, 66, 62, 83, 75, 67, 70, 65, 68, 64,
#        69, 72, 71, 19, 76, 85, 63, 90, 82, 73, 74, 78, 80, 94, 79, 77, 86,
#        95, 81, 18, 89, 84, 87, 92, 93, 88], dtype=int64)

# %%
df1= df.sort_values(by='age')

# %%
df1
# Out:
#        age      job   marital  education default  balance housing loan  \
# 42954   18  student    single    unknown      no      108      no   no
# 41273   18  student    single    unknown      no        3      no   no
# 42146   18  student    single  secondary      no      156      no   no
# 43637   18  student    single    unknown      no      348      no   no
# 40736   18  student    single    primary      no     1944      no   no
# ...    ...      ...       ...        ...     ...      ...     ...  ...
# 44420   93  retired   married    unknown      no      775      no   no
# 44262   93  retired   married    unknown      no      775      no   no
# 31233   94  retired  divorced  secondary      no     1234      no   no
# 41663   95  retired   married  secondary      no        0      no   no
# 33699   95  retired  divorced    primary      no     2282      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
df= df1.reset_index(drop=True)

# %%
df['age'].min()
# Out:
# 18

# %%
df['age'].max()
# Out:
# 95

# %% [markdown]
# - this dataset is people of age between 18 to 95

# %%
df['age'].value_counts()
# Out:
# age
# 32    2085
# 31    1996
# 33    1972
# 34    1930
# 35    1894
#       ...
# 90       2
# 92       2
# 93       2
# 95       2
# 94       1
# Name: count, Length: 77, dtype: int64

# %% [markdown]
# - most of clients are 30's

# %%
df['job'].unique()
# Out:
# array(['student', 'blue-collar', 'admin.', 'services', 'unemployed',
#        'technician', 'management', 'entrepreneur', 'self-employed',
#        'housemaid', 'retired', 'unknown'], dtype=object)

# %%
df['job'].value_counts()
# Out:
# job
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# unknown           288
# Name: count, dtype: int64

# %%
sns.countplot(x='job',data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - blue collar,managements and techncian are the most number of clients job

# %%
value_counts = df.groupby(['job', 'y']).size().reset_index(name='counts')

# %%
sns.catplot(data=value_counts, x='job', y='counts', kind='bar', hue='y')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# - managment and technicians and blue collar clients are the most sunscribed clients

# %%
df['marital'].unique()
# Out:
# array(['single', 'married', 'divorced'], dtype=object)

# %%
df['marital'].value_counts().plot(kind='pie',autopct='%1.0f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# - married couples are the most

# %%
sns.set_palette(sns.color_palette("Set1", 8))
sns.pairplot(df, hue="marital",corner=True)
plt.show()
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.hist(bins=50,figsize=(20,15))
plt.show()

# %%
sns.catplot(x='balance',y='job',data=df,kind='violin',hue='y',split=True)
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df['housing'].value_counts()
# Out:
# housing
# yes    25130
# no     20081
# Name: count, dtype: int64

# %%
df['y'].value_counts()
# Out:
# y
# no     39922
# yes     5289
# Name: count, dtype: int64

# %%
df['y'].value_counts()
# Out:
# y
# no     39922
# yes     5289
# Name: count, dtype: int64

# %%
subcribed=df[df['y']=='yes']

# %%
not_subscribed=df[df['y']=='no']

# %%
subcribed
# Out:
#        age      job   marital education default  balance housing loan  \
# 0       18  student    single   unknown      no      108      no   no
# 1       18  student    single   unknown      no        3      no   no
# 3       18  student    single   unknown      no      348      no   no
# 5       18  student    single   primary      no      608      no   no
# 6       18  student    single   primary      no      608      no   no
# ...    ...      ...       ...       ...     ...      ...     ...  ...
# 45204   92  retired   married   unknown      no      775      no   no
# 45205   92  retired   married   unknown      no      775      no   no
# 45206   93  retired   married   unknown      no      775      no   no
# 45207   93  retired   married   unknown      no      775      no   no
# 45210   95  retired  divorced   primary      no     2282      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
not_subscribed
# Out:
#        age      job   marital  education default  balance housing loan  \
# 2       18  student    single  secondary      no      156      no   no
# 4       18  student    single    primary      no     1944      no   no
# 7       18  student    single    unknown      no       35      no   no
# 9       18  student    single  secondary      no        5      no   no
# 11      18  student    single    unknown      no      438      no   no
# ...    ...      ...       ...        ...     ...      ...     ...  ...
# 45199   89  retired   married    primary      no        0      no   no
# 45200   89  retired   married   tertiary      no      553      no   no
# 45201   89  retired  divorced    primary      no     1323      no   no
# 45208   94  retired  divorced  secondary      no     1234      no   no
# 45209   95  retired   married  secondary      no        0      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
subcribed['housing'].value_counts()
# Out:
# housing
# no     3354
# yes    1935
# Name: count, dtype: int64

# %%
sns.countplot(x='housing',data=subcribed)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - even the people having house loan are also subscribed and deposited the plan

# %%
not_subscribed['housing'].value_counts()
# Out:
# housing
# yes    23195
# no     16727
# Name: count, dtype: int64

# %%
subcribed['loan'].value_counts()
# Out:
# loan
# no     4805
# yes     484
# Name: count, dtype: int64

# %%
sns.countplot(x='loan',data=subcribed)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - while comparing with the loan the clients who have loan have not subscribed only 484 number of people only subscribed

# %%
not_subscribed['loan'].value_counts()
# Out:
# loan
# no     33162
# yes     6760
# Name: count, dtype: int64

# %%
df
# Out:
#        age      job   marital  education default  balance housing loan  \
# 0       18  student    single    unknown      no      108      no   no
# 1       18  student    single    unknown      no        3      no   no
# 2       18  student    single  secondary      no      156      no   no
# 3       18  student    single    unknown      no      348      no   no
# 4       18  student    single    primary      no     1944      no   no
# ...    ...      ...       ...        ...     ...      ...     ...  ...
# 45206   93  retired   married    unknown      no      775      no   no
# 45207   93  retired   married    unknown      no      775      no   no
# 45208   94  retired  divorced  secondary      no     1234      no   no
# 45209   95  retired   married  secondary      no        0      no   no
# 45210   95  retired  divorced    primary      no     2282      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
value_counts = df.groupby(['marital', 'y']).size().reset_index(name='counts')

# %%
value_counts
# Out:
#     marital    y  counts
# 0  divorced   no    4585
# 1  divorced  yes     622
# 2   married   no   24459
# 3   married  yes    2755
# 4    single   no   10878
# 5    single  yes    1912

# %%
sns.catplot(data=value_counts, x='marital', y='counts', kind='bar', hue='y')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# - married and single clients are the most subscribed clients

# %%
df4= df.sort_values(by='balance',ascending=False)

# %%
df4
# Out:
#        age            job   marital  education default  balance housing loan  \
# 36182   51     management    single   tertiary      no   102127      no   no
# 42813   59     management   married   tertiary      no    98417      no   no
# 45176   84        retired   married  secondary      no    81204      no   no
# 45178   84        retired   married  secondary      no    81204      no   no
# 43904   60        retired   married    primary      no    71188      no   no
# ...    ...            ...       ...        ...     ...      ...     ...  ...
# 41682   57  self-employed   married   tertiary     yes    -3313     yes  yes
# 27704   43     management   married   tertiary     yes    -3372     yes   no
# 43955   60     management  divorced   tertiary      no    -4057     yes   no
# 34904   49     management   married   tertiary     yes    -6847      no  yes
# 1757    26    blue-collar    single  secondary     yes    -8019      no  yes
#
# ...

# %%
df4.head(40)
# Out:
#        age            job   marital  education default  balance housing loan  \
# 36182   51     management    single   tertiary      no   102127      no   no
# 42813   59     management   married   tertiary      no    98417      no   no
# 45176   84        retired   married  secondary      no    81204      no   no
# 45178   84        retired   married  secondary      no    81204      no   no
# 43904   60        retired   married    primary      no    71188      no   no
# 40549   56     management  divorced   tertiary      no    66721      no   no
# 37234   52    blue-collar   married    primary      no    66653      no   no
# 43010   59         admin.   married    unknown      no    64343      no   no
# 9673    32   entrepreneur    single   tertiary      no    59649      no   no
# 40826   56    blue-collar   married  secondary      no    58932      no   no
# 29379   44         admin.   married  secondary      no    58544     yes   no
# ...

# %%
df.tail(20)
# Out:
#        age      job   marital  education default  balance housing loan  \
# 45191   86  retired   married    primary      no     1255      no   no
# 45192   86  retired  divorced    primary      no        0      no   no
# 45193   87  retired   married  secondary      no      433      no   no
# 45194   87  retired   married    primary      no     2190      no   no
# 45195   87  retired   married    primary      no      230      no   no
# 45196   87  retired  divorced    primary      no     6746      no   no
# 45197   88  retired   married    primary      no      648      no   no
# 45198   88  retired   married  secondary      no      433      no   no
# 45199   89  retired   married    primary      no        0      no   no
# 45200   89  retired   married   tertiary      no      553      no   no
# 45201   89  retired  divorced    primary      no     1323      no   no
# 45202   90  retired  divorced    primary      no      712      no   no
# ...

# %%
df['contact'].unique()
# Out:
# array(['cellular', 'telephone', 'unknown'], dtype=object)

# %%
df['contact'].value_counts()
# Out:
# contact
# cellular     29285
# unknown      13020
# telephone     2906
# Name: count, dtype: int64

# %% [markdown]
# ## conclusion

# %% [markdown]
# - The marketing strategy mainly targets people in their 30s.
# - Most subscribers are blue-collar workers.
# - Married and single individuals are the primary subscribers, possibly planning to use the subscription after retirement.
# - The subscription rate is relatively low among people who take loans from the bank.
# - People with house loans are also  subscribe.
